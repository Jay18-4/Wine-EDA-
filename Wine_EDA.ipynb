# %% [markdown]
# <hr>
# <h1 style= 'font-size:35px; '><strong><u>Exploratory Data Analysis for Wine Dataset.</u></strong></h1>
# <hr>

# %% [markdown]
# <p style= 'font-size:25px; margin-left: 10px; '><strong>IRIS Dataset From UCI</strong></p>
# <hr>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file = r"C:\Users\user\Downloads\wine\wine.data"
columns = ['Class_id','Alcohol','Malic_acid','Ash','Alcalinity_of_ash','Magnesium','Total_phenols','Flavanoids','Nonflavanoid_phenols','Proanthocyanins','Color_intensity','Hue','OD280/OD315_of_diluted_wines','Proline']

# %%
df = pd.read_csv(file,names=columns,header=None)
df.head(5)
# Out:
#    Class_id  Alcohol  Malic_acid   Ash  Alcalinity_of_ash  Magnesium  \
# 0         1    14.23        1.71  2.43               15.6        127
# 1         1    13.20        1.78  2.14               11.2        100
# 2         1    13.16        2.36  2.67               18.6        101
# 3         1    14.37        1.95  2.50               16.8        113
# 4         1    13.24        2.59  2.87               21.0        118
#
#    Total_phenols  Flavanoids  Nonflavanoid_phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color_intensity   Hue  OD280/OD315_of_diluted_wines  Proline
# 0             5.64  1.04                          3.92     1065
# ...

# %% [markdown]
# <hr>
# <p style= 'font-size:20px; margin-left: 0; margin-buttom:0 '><strong>1. Data Cleaning & Inspection</strong>
#     <ul style= 'font-size:20px; margin-left: 10px; margin-buttom:0 '><strong>Tasks:</strong>
#         <li style= 'font-size:20px; margin-left: 15px; margin-buttom:0 '><strong>Check for missing values, duplicates, and data types.</strong></li>
#         <li style= 'font-size:20px; margin-left: 15px; margin-buttom:0 '><strong>Summarize the dataset (e.g., df.describe()).</strong></li>
#     </ul>
# </p>
#
# <hr>

# %%
df_null_amt = df.isnull()
df_null_amt.value_counts()
# Out:
# Class_id  Alcohol  Malic_acid  Ash    Alcalinity_of_ash  Magnesium  Total_phenols  Flavanoids  Nonflavanoid_phenols  Proanthocyanins  Color_intensity  Hue    OD280/OD315_of_diluted_wines  Proline
# False     False    False       False  False              False      False          False       False                 False            False            False  False                         False      178
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#          Class_id     Alcohol  Malic_acid         Ash  Alcalinity_of_ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total_phenols  Flavanoids  Nonflavanoid_phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %% [markdown]
# <hr>
# <p style= 'font-size:20px; margin-left: 0; margin-buttom:0 '><strong>2. Univariate Analysis</strong>
#     <ul style= 'font-size:20px; margin-left: 10px; margin-buttom:0 '><strong>Tasks:</strong>
#         <li style= 'font-size:20px; margin-left: 15px; margin-buttom:0 '><strong>Plot histograms for each feature to inspect distributions.</strong></li>
#     </ul>
# </p>
#
# <hr>

# %%
sns.histplot(data=df,x='Alcohol',hue='Class_id',kde=True,bins=10)
plt.show()

# %%
sns.histplot(data=df,x='Malic_acid',hue='Class_id',kde=True,bins=10)
plt.show()

# %%
sns.histplot(data=df,x='Ash',hue='Class_id',kde=True,bins=10)
plt.show()

# %%
sns.histplot(data=df,x='Alcalinity_of_ash',hue='Class_id',kde=True,bins=10)
plt.show()

# %%
sns.histplot(data=df,x='Magnesium',hue='Class_id',kde=True,bins=10)
plt.show()

# %%
sns.histplot(data=df,x='Total_phenols',hue='Class_id',kde=True,bins=10)
plt.show()

# %%
sns.histplot(data=df,x='Flavanoids',hue='Class_id',kde=True,bins=10)
plt.show()

# %%
sns.histplot(data=df,x='Nonflavanoid_phenols',hue='Class_id',kde=True,bins=10)
plt.show()

# %%
sns.histplot(data=df,x='Proanthocyanins',hue='Class_id',kde=True,bins=10)
plt.show()

# %%
sns.histplot(data=df,x='Color_intensity',hue='Class_id',kde=True,bins=10)
plt.show()

# %%
sns.histplot(data=df,x='Hue',hue='Class_id',kde=True,bins=10)
plt.show()

# %%
sns.histplot(data=df,x='OD280/OD315_of_diluted_wines',hue='Class_id',kde=True,bins=10)
plt.show()

# %%
sns.histplot(data=df,x='Proline',hue='Class_id',kde=True,bins=10)
plt.show()

# %% [markdown]
# <hr>
# <p style= 'font-size:20px; margin-left: 0; margin-buttom:0 '><strong>3. Bivariate Analysis</strong>
#     <ul style= 'font-size:20px; margin-left: 10px; margin-buttom:0 '><strong>Tasks:</strong>
#         <li style= 'font-size:20px; margin-left: 15px; margin-buttom:0 '><strong>Compare each feature against the wine class (target).</strong></li>
#         <li style= 'font-size:20px; margin-left: 15px; margin-buttom:0 '><strong>Example: Create boxplots or KDE plots for Alcohol, Flavanoids, Color Intensity, etc., grouped by wine class.</strong></li>
#     </ul>
# </p>
#
# <hr>

# %%
sns.boxplot(data=df,x="Class_id",y='Alcohol')
plt.show()

# %%
sns.boxplot(data=df,x="Class_id",y='Malic_acid')
plt.show()

# %%
sns.boxplot(data=df,x="Class_id",y='Ash')
plt.show()

# %%
sns.boxplot(data=df,x="Class_id",y='Alcalinity_of_ash')
plt.show()

# %%
sns.boxplot(data=df,x="Class_id",y='Magnesium')
plt.show()

# %%
sns.boxplot(data=df,x="Class_id",y='Total_phenols')
plt.show()

# %%
sns.boxplot(data=df,x="Class_id",y='Flavanoids')
plt.show()

# %%
sns.boxplot(data=df,x="Class_id",y='Nonflavanoid_phenols')
plt.show()

# %%
sns.boxplot(data=df,x="Class_id",y='Proanthocyanins')
plt.show()

# %%
sns.boxplot(data=df,x="Class_id",y='Color_intensity')
plt.show()

# %%
sns.boxplot(data=df,x="Class_id",y='Hue')
plt.show()

# %%
sns.boxplot(data=df,x="Class_id",y='OD280/OD315_of_diluted_wines')
plt.show()

# %%
sns.boxplot(data=df,x="Class_id",y='Proline')
plt.show()

# %% [markdown]
# <hr>
# <p style= 'font-size:20px; margin-left: 0; margin-buttom:0 '><strong>4. Correlation Analysis</strong>
#     <ul style= 'font-size:20px; margin-left: 10px; margin-buttom:0 '><strong>Tasks:</strong>
#         <li style= 'font-size:20px; margin-left: 15px; margin-buttom:0 '><strong>Identify relationships between features.</strong></li>
#         <li style= 'font-size:20px; margin-left: 15px; margin-buttom:0 '><strong>Highlight features with high correlations (e.g., correlations > 0.7).</strong></li>
#     </ul>
# </p>
#
# <hr>

# %%
for i in df:
    print(df[i].corr(df['Class_id']),f'-- {i}')
# Out:
# 1.0 -- Class_id
# -0.3282219408900193 -- Alcohol
# 0.4377762048410647 -- Malic_acid
# -0.04964322102407744 -- Ash
# 0.5178591098214518 -- Alcalinity_of_ash
# -0.2091793902949301 -- Magnesium
# -0.7191633405539714 -- Total_phenols
# -0.8474975401417579 -- Flavanoids
# 0.48910915886069084 -- Nonflavanoid_phenols
# -0.4991298238591702 -- Proanthocyanins
# 0.26566756917598955 -- Color_intensity
# -0.6173692102858322 -- Hue
# -0.7882295886876622 -- OD280/OD315_of_diluted_wines
# -0.6337167849870337 -- Proline

# %% [markdown]
# <hr>
# <ul style= "font-size:20px">
#     Features with the highest correlations<br>
#     <li style="margin-left:30px">Flavanoids</li>
#     <li style="margin-left:30px">OD280/OD315_of_diluted_wines</li>
#     <li style="margin-left:30px">Total_phenols</li>
# </ul>
# <hr>

# %% [markdown]
# <hr>
# <p style= 'font-size:20px; margin-left: 0; margin-buttom:0 '><strong>Problem 1: Which features are most useful for classifying wine types?</strong>
#     <ul style= 'font-size:20px; margin-left: 10px; margin-buttom:0 '><strong>Solution:</strong>
#         <li style= 'font-size:20px; margin-left: 30px; margin-buttom:0 '><strong>Key Features: Flavanoids, Total Phenols, and OD280/OD315 of diluted wines.</strong></li>
#         <li style= 'font-size:20px; margin-left: 30px; margin-buttom:0 '><strong>Class Characteristics:</strong>
#             <li style= 'font-size:20px; margin-left: 50px; margin-buttom:0 '><strong>Class 1: Highest levels of Flavanoids and Total Phenols.</strong></li>
#             <li style= 'font-size:20px; margin-left: 50px; margin-buttom:0 '><strong>Class 2: Lowest Alcohol and Color Intensity</strong></li>
#             <li style= 'font-size:20px; margin-left: 50px; margin-buttom:0 '><strong>Class 3: Lowest Flavanoids and Total Phenols, but highest Color Intensity.</strong></li>
#         </li>
#     </ul>
# </p>
#
# <hr>

# %% [markdown]
# <hr>
# <p style= 'font-size:20px; margin-left: 0; margin-buttom:0 '><strong>Problem 2: How do Alcohol and Color Intensity vary across classes?</strong>
#     <ul style= 'font-size:20px; margin-left: 10px; margin-buttom:0 '><strong>Solution:</strong>
#         <li style= 'font-size:20px; margin-left: 30px; margin-buttom:0 '><strong>Class 1 has the highest Alcohol.</strong></li>
#         <li style= 'font-size:20px; margin-left: 30px; margin-buttom:0 '><strong>Class 2 has the lowest levels of both Alcohol and Color Intensity.</strong></li>
#         <li style= 'font-size:20px; margin-left: 30px; margin-buttom:0 '><strong>Class 3 has the highest Color Intensity.</strong></li>
#     </ul>
# </p>
#
# <hr>

# %% [markdown]
# <hr>
# <p style= 'font-size:20px; margin-left: 0; margin-buttom:0 '><strong>Problem 3: Are there strong correlations between certain features?</strong>
#     <ul style= 'font-size:20px; margin-left: 10px; margin-buttom:0 '><strong>Solution:</strong>
#         <li style= 'font-size:20px; margin-left: 30px; margin-buttom:0 '><strong>High Correlations (> 0.7):</strong>
#             <li style= 'font-size:20px; margin-left: 50px; margin-buttom:0 '><strong>Flavanoids ↔ Total Phenols.</strong></li>
#             <li style= 'font-size:20px; margin-left: 50px; margin-buttom:0 '><strong>OD280/OD315 ↔ Alcohol.</strong></li>
#             <li style= 'font-size:20px; margin-left: 50px; margin-buttom:0 '><strong>OD280/OD315 ↔ Flavanoids.</strong></li>
#         </li>
#         <li style= 'font-size:20px; margin-left: 30px; margin-buttom:0 '><strong>These features are highly predictive of the wine class.</strong></li>
#     </ul>
# </p>
#
# <hr>

# %% [markdown]
# <hr>
# <h1 style= 'font-size:35px; margin-left: 5px; margin-buttom:0 '><strong>Conclusion</strong></h1>
# <hr>

# %% [markdown]
# <h2 style= 'font-size:20px; margin-left: 10px; margin-buttom:0; margin-top:0; line-height: 1.5 '><strong>
#     The analysis shows that Flavanoids, Total Phenols, and OD280/OD315 are key features for<br>
#     differentiating wine classes. Class separation is clear for these features, but overlap may occur for other<br>
#     features like Alcohol and Color Intensity. High correlations among predictive features provide further<br>
#     insights into the dataset structure.<br>
#     These insights could guide the development of a classification model.
# </strong></h2>
# <hr>
